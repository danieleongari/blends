# %% [markdown]
# # 02 - Generate samples with valid quantities

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('..')

import json

from blends.base import dict_to_blend, blend_to_dict

myblend_dict = json.load(open('../data/blend_example_001.json'))
myblend = dict_to_blend(myblend_dict)

# %%
from blends.sample import generate_samples

df = generate_samples(myblend, nsamples=1000, verbose=True)
df
# Out:
# Method: absolute, 557/1000 successful samples generated.
#      Solvent-1  Solvent-2  Solvent-3   Comp-A1   Comp-A2   Comp-A3  \
# 0     0.000000   0.000000   0.274904  0.084007  0.298383  0.083350
# 1     0.000000   0.298936   0.000000  0.231322  0.187344  0.062013
# 2     0.000000   0.249334   0.000000  0.114451  0.132059  0.240837
# 3     0.000000   0.201442   0.000000  0.009639  0.454381  0.051177
# 4     0.203314   0.000000   0.000000  0.421079  0.031747  0.061496
# ..         ...        ...        ...       ...       ...       ...
# 552   0.234020   0.000000   0.000000  0.012701  0.407818  0.083980
# 553   0.000000   0.297865   0.000000  0.113819  0.077617  0.379635
# 554   0.000000   0.270199   0.000000  0.105132  0.124277  0.305359
# 555   0.218045   0.000000   0.000000  0.085431  0.130247  0.306420
# 556   0.256647   0.000000   0.000000  0.231616  0.069847  0.114677
#
#      Component-B  Comp-C1-1  Comp-C1-2   Comp-C2  Qtot
# 0       0.255462   0.003161   0.000732  0.000000   1.0
# 1       0.123374   0.000000   0.000000  0.097011   1.0
# 2       0.218333   0.019240   0.025746  0.000000   1.0
# 3       0.244761   0.035289   0.003311  0.000000   1.0
# 4       0.145611   0.123488   0.013265  0.000000   1.0
# ..           ...        ...        ...       ...   ...
# 552     0.158231   0.022078   0.081171  0.000000   1.0
# 553     0.123909   0.000000   0.000000  0.007155   1.0
# 554     0.193753   0.000331   0.000950  0.000000   1.0
# 555     0.187096   0.035553   0.037208  0.000000   1.0
# 556     0.161516   0.000000   0.000000  0.165698   1.0
#
# [557 rows x 11 columns]
